# %% [markdown]
# <a href="https://colab.research.google.com/github/Manancourt/R-files-from-YouTube/blob/main/Rock%2C_Paper%2C_Scissors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Rock, Paper, Scissors
# Run the code in the cell below to load the game. To start the game, run the function in the bottom cell by pressing the play button on the left.

# %%
########################## [RUN THIS FIRST] ####################################
from numpy import random
import time
import sys

### RNGs ####################################
def coinFlip():
  flip = random.randint(0, 11)
  return(flip)

def compTurn():
  comp_turn = random.randint(0, 3)
  return(comp_turn)

### Print symbols & functions ###############
rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''
paper = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''
scissors = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''

title_disp = '''
┬─┐┌─┐┌─┐┬┌─              
├┬┘│ ││  ├┴┐              
┴└─└─┘└─┘┴ ┴┘             
  ┌─┐┌─┐┌─┐┌─┐┬─┐         
  ├─┘├─┤├─┘├┤ ├┬┘         
  ┴  ┴ ┴┴  └─┘┴└─┘        
    ┌─┐┌─┐┬┌─┐┌─┐┌─┐┬─┐┌─┐
    └─┐│  │└─┐└─┐│ │├┬┘└─┐
    └─┘└─┘┴└─┘└─┘└─┘┴└─└─┘
'''

winner_disp = '''
██████╗██╗   ██╗ ██████╗██╗  ██╗     ██████╗ ███████╗███╗   ██╗██╗██╗   ██╗███████╗   
██╔════╝██║   ██║██╔════╝██║  ██║    ██╔════╝ ██╔════╝████╗  ██║██║██║   ██║██╔════╝   
███████╗██║   ██║██║     ███████║    ██║  ███╗█████╗  ██╔██╗ ██║██║██║   ██║███████╗   
╚════██║██║   ██║██║     ██╔══██║    ██║   ██║██╔══╝  ██║╚██╗██║██║██║   ██║╚════██║   
███████║╚██████╔╝╚██████╗██║  ██║    ╚██████╔╝███████╗██║ ╚████║██║╚██████╔╝███████║▄█╗
╚══════╝ ╚═════╝  ╚═════╝╚═╝  ╚═╝     ╚═════╝ ╚══════╝╚═╝  ╚═══╝╚═╝ ╚═════╝ ╚══════╝╚═╝
                                                                                       
██╗   ██╗ ██████╗ ██╗   ██╗    ██╗    ██╗██╗███╗   ██╗██╗                              
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║    ██║██║████╗  ██║██║                              
 ╚████╔╝ ██║   ██║██║   ██║    ██║ █╗ ██║██║██╔██╗ ██║██║                              
  ╚██╔╝  ██║   ██║██║   ██║    ██║███╗██║██║██║╚██╗██║╚═╝                              
   ██║   ╚██████╔╝╚██████╔╝    ╚███╔███╔╝██║██║ ╚████║██╗                              
   ╚═╝    ╚═════╝  ╚═════╝      ╚══╝╚══╝ ╚═╝╚═╝  ╚═══╝╚═╝                              
                                                                 
'''

loser_disp = '''
    ███        ▄████████ ▄██   ▄           ▄████████    ▄██████▄     ▄████████  ▄█  ███▄▄▄▄   
▀█████████▄   ███    ███ ███   ██▄        ███    ███   ███    ███   ███    ███ ███  ███▀▀▀██▄ 
   ▀███▀▀██   ███    ███ ███▄▄▄███        ███    ███   ███    █▀    ███    ███ ███▌ ███   ███ 
    ███   ▀  ▄███▄▄▄▄██▀ ▀▀▀▀▀▀███        ███    ███  ▄███          ███    ███ ███▌ ███   ███ 
   _$$ |_       $$ |__$$ |$$ \__$$ |$$ |$$ |  $$ |  $$ |/  |
  / $$   |      $$    $$/ $$    $$/ $$ |$$ |  $$ |  $$  $$/ 
  $$$$$$/       $$$$$$$/   $$$$$$/  $$/ $$/   $$/    $$$$/  
                $$ |                                        
                $$ |                                        
                $$/                                         
  '''
  two_p = '''
    ______                             __              __               
   /      \                           /  |            /  |              
  /$$$$$$  |        ______    ______  $$/  _______   _$$ |_     _______ 
  $$____$$ |       /      \  /      \ /  |/       \ / $$   |   /       |
  /    $$/       /$$$$$$  |/$$$$$$  |$$ |$$$$$$$  |$$$$$$/   /$$$$$$$/ 
  /$$$$$$/        $$ |  $$ |$$ |  $$ |$$ |$$ |  $$ |  $$ | __ $$      \ 
  $$ |_____       $$ |__$$ |$$ \__$$ |$$ |$$ |  $$ |  $$ |/  | $$$$$$  |
  $$       |      $$    $$/ $$    $$/ $$ |$$ |  $$ |  $$  $$/ /     $$/ 
  $$$$$$$$/       $$$$$$$/   $$$$$$/  $$/ $$/   $$/    $$$$/  $$$$$$$/  
                  $$ |                                                  
                  $$ |                                                  
                  $$/                                                   
  '''
  three_p = '''
     ______                             __              __               
    /      \                           /  |            /  |              
  /$$$$$$  |        ______    ______  $$/  _______   _$$ |_     _______ 
  $$ ___$$ |       /      \  /      \ /  |/       \ / $$   |   /       |
    /   $$<       /$$$$$$  |/$$$$$$  |$$ |$$$$$$$  |$$$$$$/   /$$$$$$$/ 
   _$$$$$  |      $$ |  $$ |$$ |  $$ |$$ |$$ |  $$ |  $$ | __ $$      \ 
  /  \__$$ |      $$ |__$$ |$$ \__$$ |$$ |$$ |  $$ |  $$ |/  | $$$$$$  |
  $$    $$/       $$    $$/ $$    $$/ $$ |$$ |  $$ |  $$  $$/ /     $$/ 
   $$$$$$/        $$$$$$$/   $$$$$$/  $$/ $$/   $$/    $$$$/  $$$$$$$/  
                  $$ |                                                  
                  $$ |                                                  
                  $$/                                                   
  '''
  if your_wins == 1:
    print(one_p)
  elif your_wins == 2:
    print(two_p)
  elif your_wins == 3:
    print(three_p)

#Opponent points
def printLoss(comp_wins):
  one_p = '''
    ,  ,  _,   ,  ,  ,_        _,   ,_   ,_    _,  ,  ,   _, ,  ,  ___, 
    \_/  / \,  |  |  |_)      / \,  |_)  |_)  / \, |\ |  /_, |\ | ' |   
   , /` '\_/  '\__| '| \     '\_/  '|   '|   '\_/  |'\| '\_  |'\|   |   
   (_/    '        `  '  `     '     '    '    '    '  `    ` '  `   '   
                                                                        
   , ,   _      _,      _,  ,  ,   _,     ,_    _,   ___, ,  ,  ___,    
   |_|, '|\    (_,     / \, |\ |  /_,     |_)  / \, ' |   |\ | ' |      
  '| |   |-\    _)    '\_/  |'\| '\_     '|   '\_/   _|_, |'\|   |      
   ' `   '  `  '       '    '  `    `     '    '    '     '  `   '    
  '''
  two_p = '''
    ,  ,  _,   ,  ,  ,_        _,   ,_   ,_    _,  ,  ,   _, ,  ,  ___,    
    \_/  / \,  |  |  |_)      / \,  |_)  |_)  / \, |\ |  /_, |\ | ' |      
   , /` '\_/  '\__| '| \     '\_/  '|   '|   '\_/  |'\| '\_  |'\|   |      
  (_/    '        `  '  `     '     '    '    '    '  `    ` '  `   '      
                                                                          
   , ,   _      _,     ___, ,  ,   _,      ,_    _,   ___, ,  ,  ___,   _, 
   |_|, '|\    (_,    ' |   | ,|  / \,     |_)  / \, ' |   |\ | ' |    (_, 
  '| |   |-\    _)      |   |/\| '\_/     '|   '\_/   _|_, |'\|   |     _) 
  ' `   '  `  '        '   '  `  '        '    '    '     '  `   '    '  
  '''
  three_p = '''
    ,  ,  _,   ,  ,  ,_        _,   ,_   ,_    _,  ,  ,   _, ,  ,  ___,               
    \_/  / \,  |  |  |_)      / \,  |_)  |_)  / \, |\ |  /_, |\ | ' |                 
   , /` '\_/  '\__| '| \     '\_/  '|   '|   '\_/  |'\| '\_  |'\|   |                 
  (_/    '        `  '  `     '     '    '    '    '  `    ` '  `   '                 
                                                                                      
   , ,   _      _,     ___,  , ,   ,_     _,   _,     ,_    _,   ___, ,  ,  ___,   _, 
   |_|, '|\    (_,    ' |    |_|,  |_)   /_,  /_,     |_)  / \, ' |   |\ | ' |    (_, 
  '| |   |-\    _)      |   '| |  '| \  '\_  '\_     '|   '\_/   _|_, |'\|   |     _) 
   ' `   '  `  '        '    ' `   '  `    `    `     '    '    '     '  `   '    '   
  '''
  if comp_wins == 1:
    print(one_p)
  elif comp_wins == 2:
    print(two_p)
  elif comp_wins == 3:
    print(three_p)

#Slow printing
def slowPrint(text, delay):
  for char in text:
      sys.stdout.write(char)
      time.sleep(delay)

### Game #####################################
def rockPaperScissors():
  
  #Reset score
  your_wins = 0
  comp_wins = 0 

  print("\n")
  print("Welcome to: \n", title_disp)

  while (your_wins < 3) and (comp_wins < 3):

    #PLAYER CHOSES
    your_choice = int(input("Type 0 for rock, 1 for paper, or 2 for scissors. \n"))

    ###ROCK###
    if your_choice == 0:       
      #Loading bar
      slowPrint(loading_rps, 0.068)
      print("\n   You picked" + '\033[1m' + " rock." + '\033[0m', rock)
      #COMP CHOSES
      comp_choice = compTurn()
      #PAPER
      if comp_choice == 1:
        comp_wins = comp_wins + 1
        print("   Your opponent picked" + '\033[1m' + " paper." + '\033[0m', paper)
        print("You" + '\033[1m' + " lose " + '\033[0m' + "the round. \n")
        printLoss(comp_wins)
      #SCISSORS
      elif comp_choice == 2:
        your_wins = your_wins + 1
        print("   Your opponent picked" + '\033[1m' + " scissors." + '\033[0m', scissors)
        print("You" + '\033[1m' + " win " + '\033[0m' + "the round. You have:")
        printPoints(your_wins)
      #ROCK
      else: 
        print("   Your opponent picked" + '\033[1m' + " rock." + '\033[0m', rock)
        print("It's a draw! \n")

    ###PAPER###
    elif your_choice == 1:
      #Loading bar
      slowPrint(loading_rps, 0.068)
      print("\n   You picked" + '\033[1m' + " paper." + '\033[0m', paper)
      #COMP CHOSES
      comp_choice = compTurn()
      #Comp = PAPER
      if comp_choice == 1:
        print("   Your opponent picked" + '\033[1m' + " paper." + '\033[0m', paper)
        print("It's a draw! \n")
      #Comp = SCISSORS
      elif comp_choice == 2:
        comp_wins = comp_wins + 1
        print("   Your opponent picked" + '\033[1m' + " scissors." + '\033[0m', scissors)
        print("You" + '\033[1m' + " lose " + '\033[0m' + "the round. \n")
        printLoss(comp_wins)
      #Comp = ROCK
      else:
        your_wins = your_wins + 1
        print("   Your opponent picked" + '\033[1m' + " rock." + '\033[0m', rock)
        print("You" + '\033[1m' + " win " + '\033[0m' + "the round. You have:")
        printPoints(your_wins)

    ###SCISSORS###
    else:
      #Loading bar
      slowPrint(loading_rps, 0.068)
      print("\n   You picked" + '\033[1m' + " scissors." + '\033[0m', scissors)  
      #COMP CHOSES
      comp_choice = compTurn()
      #ROCK
      if comp_choice == 0:
        comp_wins = comp_wins + 1
        print("   Your opponent picked" + '\033[1m' + " rock." + '\033[0m', rock)
        print("You" + '\033[1m' + " lose " + '\033[0m' + "the round. \n")
        printLoss(comp_wins)
      #PAPER  
      elif comp_choice ==1:
        your_wins = your_wins + 1
        print("   Your opponent picked" + '\033[1m' + " paper." + '\033[0m', paper)
        print("You" + '\033[1m' + " win " + '\033[0m' + "the round. You have:")
        printPoints(your_wins)
      #SCISSORS
      else:
        print("   Your opponent picked" + '\033[1m' + " scissors." + '\033[0m', scissors)
        print("It's a" + '\033[1m' + " draw." + '\033[0m' + "\n")

#Game over conditions
  if your_wins > comp_wins:
    print(winner_disp)
  elif comp_wins > your_wins:
    print(loser_disp)
  else:
    print(draw_disp)

# %%
############################# [PLAY GAME] ######################################
rockPaperScissors()
# Out:
# Welcome to:
#
# ┬─┐┌─┐┌─┐┬┌─
# ├┬┘│ ││  ├┴┐
# ┴└─└─┘└─┘┴ ┴┘
#   ┌─┐┌─┐┌─┐┌─┐┬─┐
#   ├─┘├─┤├─┘├┤ ├┬┘
#   ┴  ┴ ┴┴  └─┘┴└─┘
#     ┌─┐┌─┐┬┌─┐┌─┐┌─┐┬─┐┌─┐
#     └─┐│  │└─┐└─┐│ │├┬┘└─┐
#     └─┘└─┘┴└─┘└─┘└─┘┴└─└─┘
#
# Type 0 for rock, 1 for paper, or 2 for scissors.
# 0
# Rock... paper... scissors!
#
#    You picked rock.
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
#    Your opponent picked paper.
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# You lose the round.
#
#
#     ,  ,  _,   ,  ,  ,_        _,   ,_   ,_    _,  ,  ,   _, ,  ,  ___,
#     \_/  / \,  |  |  |_)      / \,  |_)  |_)  / \, |\ |  /_, |\ | ' |
#    , /` '\_/  '\__| '| \     '\_/  '|   '|   '\_/  |'\| '\_  |'\|   |
#    (_/    '        `  '  `     '     '    '    '    '  `    ` '  `   '
#
#    , ,   _      _,      _,  ,  ,   _,     ,_    _,   ___, ,  ,  ___,
# ...
